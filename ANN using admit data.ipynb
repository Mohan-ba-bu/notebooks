# %%
import pandas as pd
import numpy as np
import pydataset

# %%
# df=pydataset.data('iris')
df = pd.read_csv('admit.csv')

# %%
df.columns = [ i.lower().strip().replace('.','_') for i in df.columns]

# %%
df
# Out:
#      gre  toefl  univ_rating  sop  lor  cgpa  research  admit
# 0    337    118            4  4.5  4.5  9.65         1      1
# 1    324    107            4  4.0  4.5  8.87         1      1
# 2    316    104            3  3.0  3.5  8.00         1      1
# 3    322    110            3  3.5  2.5  8.67         1      1
# 4    314    103            2  2.0  3.0  8.21         0      0
# ..   ...    ...          ...  ...  ...   ...       ...    ...
# 395  324    110            3  3.5  3.5  9.04         1      1
# 396  325    107            3  3.0  3.5  9.11         1      1
# 397  330    116            4  5.0  4.5  9.45         1      1
# 398  312    103            3  3.5  4.0  8.78         0      0
# 399  333    117            4  5.0  4.0  9.66         1      1
#
# [400 rows x 8 columns]

# %%
# df.reset_index(drop=True,inplace= True)

# %%
df
# Out:
#      gre  toefl  univ_rating  sop  lor  cgpa  research  admit
# 0    337    118            4  4.5  4.5  9.65         1      1
# 1    324    107            4  4.0  4.5  8.87         1      1
# 2    316    104            3  3.0  3.5  8.00         1      1
# 3    322    110            3  3.5  2.5  8.67         1      1
# 4    314    103            2  2.0  3.0  8.21         0      0
# ..   ...    ...          ...  ...  ...   ...       ...    ...
# 395  324    110            3  3.5  3.5  9.04         1      1
# 396  325    107            3  3.0  3.5  9.11         1      1
# 397  330    116            4  5.0  4.5  9.45         1      1
# 398  312    103            3  3.5  4.0  8.78         0      0
# 399  333    117            4  5.0  4.0  9.66         1      1
#
# [400 rows x 8 columns]

# %%
x=df.iloc[:,:-1]
y= df.iloc[:,-1]

# %%
from sklearn.model_selection import *
from sklearn.metrics import *

x_train,x_test, y_train, y_test = train_test_split(x,y,train_size=0.70,random_state=0)

# %%
x_train.shape
# Out:
# (280, 7)

# %%
from sklearn.preprocessing import *

# %%
# MinMax Scaling
ms= MinMaxScaler()
ms.fit(x_train)
x_train_scaled = pd.DataFrame(ms.transform(x_train),columns=x_train.columns, index= x_train.index)

# %%
# ms.fit(x_test)
x_test_scaled = pd.DataFrame(ms.transform(x_test),columns=x_test.columns, index= x_test.index)

# %%
from keras import models
from keras import layers
from keras.utils import to_categorical

# %%
# converting into keras readable format
y_train_new = to_categorical(y_train)
y_test_new = to_categorical(y_test)

# %%
network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(7,)))
network.add(layers.Dense(256, activation='relu'))
network.add(layers.Dense(128, activation='relu'))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(32, activation='relu'))
network.add(layers.Dense(2, activation='sigmoid'))

# %%
network.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['AUC'])

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               4096
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 2)                 66
#
# ...
# Total params: 178722 (698.13 KB)
# Trainable params: 178722 (698.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
network.fit(x_train_scaled,y_train_new, epochs = 20, batch_size=100)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 1s 13ms/step - loss: 0.6877 - auc: 0.5589
# Epoch 2/20
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6474 - auc: 0.7414
# Epoch 3/20
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6066 - auc: 0.7649
# Epoch 4/20
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5675 - auc: 0.7745
# Epoch 5/20
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5357 - auc: 0.8054
# Epoch 6/20
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5255 - auc: 0.8070
# Epoch 7/20
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5098 - auc: 0.8342
# Epoch 8/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4953 - auc: 0.8244
# Epoch 9/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4767 - auc: 0.8587
# Epoch 10/20
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4508 - auc: 0.8720
# Epoch 11/20
# ...

# %%
acc_train = accuracy_score(train_y,pred_train_label)
acc_test = accuracy_score(test_y,pred_test_label

# %%
pred_train = logimodel.predict(coded_train_x)
pred_test = logimodel.predict(coded_test_x)

# %%
test_loss, test_acc = network.evaluate(x_test_scaled,y_test_new)
print('test_acc:' , test_acc)
# Out:
# 4/4 [==============================] - 0s 0s/step - loss: 0.4273 - auc: 0.8882
# test_acc: 0.8881597518920898

# %%
accuracy_score(y_train,pred_class)
# Out:
# 0.825

# %%
y_train
# Out:
# 92     0
# 223    1
# 234    1
# 232    0
# 377    0
#       ..
# 323    0
# 192    1
# 117    0
# 47     1
# 172    1
# Name: admit, Length: 280, dtype: int64

# %%
pred_train = network.predict(x_train_scaled)
# Out:
# 9/9 [==============================] - 0s 519us/step

# %%
pred_train
# Out:
# array([[0.88683826, 0.12191859],
#        [0.862629  , 0.14443448],
#        [0.02680017, 0.97613627],
#        [0.83421516, 0.17119963],
#        [0.8281198 , 0.19268577],
#        [0.02793443, 0.9749946 ],
#        [0.02527309, 0.9773773 ],
#        [0.5637902 , 0.44947872],
#        [0.35369837, 0.6334924 ],
#        [0.8567283 , 0.16310261],
#        [0.03216699, 0.97097427],
#        [0.78407466, 0.22198382],
#        [0.5635522 , 0.43776473],
#        [0.86523545, 0.1503263 ],
#        [0.09672976, 0.9077884 ],
#        [0.8293859 , 0.17556848],
#        [0.06002952, 0.9444894 ],
#        [0.69361806, 0.32341492],
#        [0.84563446, 0.16291161],
#        [0.3847027 , 0.5991163 ],
#        [0.05721848, 0.946971  ],
#        [0.31117362, 0.67489976],
#        [0.83320016, 0.17829035],
#        [0.5049468 , 0.4974969 ],
#        [0.25786725, 0.737515  ],
#        [0.82396966, 0.18103543],
#        [0.81369156, 0.18819955],
#        [0.0779708 , 0.92807466],
# ...

# %%
pred_class = []
for i in range(len(y_train)):
    pred_class.append(np.argmax(pred_train[i]))

# %%
from sklearn.metrics import classification_report
print(classification_report(x_train_scaled,pred_class))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 from sklearn.metrics import classification_report
# ----> 2 print(classification_report(x_train_scaled,pred_class))
#
# File ~\anaconda3\envs\DL\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
# ...
